# %%
kota = " JaKaRtA, baNDunG, sUrAbAyA, meDaN, mAkAsSaR, yOGyaKaRtA,  KudUs   "
kota_spasi = kota.strip()

if any(char.isdigit() for char in kota_spasi): print("kota tidak mengandung angka")
else : kota_title = kota_spasi.title()

print(kota_title)
# Out:
# Jakarta, Bandung, Surabaya, Medan, Makassar, Yogyakarta,  Kudus
