# %%
nama = input("Masukkan nama kamu: ")
kelas = input("Masukkan kelas kamu: ")
umur = input("Masukkan umur kamu: ")
lagu_favorit = input("Masukkan lagu favorit kamu: ")

print(nama)
print(kelas)
print(umur)
print(lagu_favorit)
